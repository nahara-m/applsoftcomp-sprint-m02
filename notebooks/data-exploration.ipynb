# %%
#check 1d-data.csv dataset

import pandas as pd
df_1d = pd.read_csv('./data/1d-data.csv')
print(df_1d.head())
# Out:
#           value  group
# 0      4.564090  cases
# 1   1040.947860  cases
# 2   3117.665150  cases
# 3     67.501829  cases
# 4  10096.092602  cases

# %%
df_1d.describe()
# Out:
#               value
# count     20.000000
# mean    5669.799506
# std     9384.638717
# min        4.564090
# 25%      201.628294
# 50%     2589.403022
# 75%     5662.118287
# max    35764.919601
